# %%
from __future__ import annotations

from joa_qartod_config.qartod import choose_stream, config_generator

# %%
stream = choose_stream()

# %%
stream.value

# %%
output = config_generator(stream=stream.value)

# %%
output.value
